# %% [markdown]
# Desafio 1

# %%
text = ' texto    '

text.strip().upper()
# Out:
# 'TEXTO'

# %% [markdown]
# Desafio 2

# %%
text2 = 'João,30,Recife'

for text in text2.split(','):
  print(text)
# Out:
# João
# 30
# Recife

# %% [markdown]
# Desafio 3

# %%
text3 = 'python é incrível'.lower()

vogais = ['a', 'e', 'i', 'o', 'u', 'á', 'é', 'í', 'ó', 'â', 'ê', 'ô', 'à']

quant_vogais = text3.count('a') + text3.count('e') + text3.count('i') + text3.count('o') + text3.count('u')

print(quant_vogais)
# Out:
# 3
