# %%
#desafio 2 de loop em python

total_sales = 0
sale = None

print('caso digite 0(zero), o programa será parado')

while sale != 0:
  sale = float(input('Valor da venda(R$): '))

  total_sales += sale

print(f'Total em vendas(R$): {total_sales:.2f}')
# Out:
# caso digite 0(zero), o programa será parado
# Valor da venda(R$): 1212
# Valor da venda(R$): 11
# Valor da venda(R$): 0
