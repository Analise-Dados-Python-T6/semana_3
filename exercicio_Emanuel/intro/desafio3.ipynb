# %%
name = input('Nome: ')
age = int(input('Idade: '))
city = input('Cidade: ')
last_purchase = float(input('Valor da ultima compra(R$): '))

print(f'\n\tNome: {name}\n\tIdade: {age}\n\tCidade: {city}\n\tValor da ultima compra: R$ {last_purchase:.2f}')
# Out:
# Nome: emanuel
# Idade: 24
# Cidade: lages
# Valor da ultima compra(R$): 10
#
# 	Nome: emanuel
# 	Idade: 24
# 	Cidade: lages
# 	Valor da ultima compra: R$ 10.00
