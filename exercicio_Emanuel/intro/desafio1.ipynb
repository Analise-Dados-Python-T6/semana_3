# %%
total_revenue = float(input('faturamento total(R$): '))
total_products = float(input('Quantidade total de produtos(un.): '))

print(f'O ticket médio é {total_revenue/total_products:.2f} R$/un.')
# Out:
# faturamento total(R$): 1000
# Quantidade total de produtos(un.): 2
# O ticket médio é 500.0 R$/un.
