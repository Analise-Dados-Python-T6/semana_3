# %%
products = ['mouse', 'smartphone', 'notebook', 'protetor de tela', 'SSD-120GB']

products[2] = 'cadeira gamer'

# print(products)

products.append('teclado mecânico')

print(f'Lista: {products}\nTamanho da lista: {len(products)}')
# Out:
# Lista: ['mouse', 'smartphone', 'cadeira gamer', 'protetor de tela', 'SSD-120GB', 'teclado mecânico']
# Tamanho da lista: 6
