# %%
# Retorno simulado de uma API de Vendas
payload_api = {
    "metadata": {
        "status_code": 200,
        "servidor": "aws-sa-east-1",
        "data_extracao": "2026-08-04"
    },
    "empresa": "TechData Solutions",
    "localizacoes": [
        {"tipo": "Matriz", "coordenadas": (-22.9068, -43.1729)}, # RJ
        {"tipo": "Filial", "coordenadas": (-23.5505, -46.6333)}  # SP
    ],
    "faturamento_diario_milhares": [12.5, 14.2, 10.8, 15.1, 19.5],
    "emails_clientes_recentes": ["ana@tech.com", "carlos@tech.com", "ana@tech.com", "bruno@tech.com", "carlos@tech.com", "ana@tech.com"]
}

for data in payload_api:
  if data == 'localizacoes':
    for sub_data in payload_api[data]:
      if sub_data['tipo'] == 'Filial':
        print(sub_data['coordenadas'])

#sum of initial and last revenue
sum_revenue = payload_api['faturamento_diario_milhares'][0] + payload_api['faturamento_diario_milhares'][-1]

print(sum_revenue)

#create a list of unique emails
unique_emails = set(payload_api['emails_clientes_recentes'])

print(unique_emails)
# Out:
# (-23.5505, -46.6333)
# 32.0
# {'bruno@tech.com', 'carlos@tech.com', 'ana@tech.com'}
