# %%
#list not treated
raw_list = ['test@gmail.com', 'emailcriativo@gmail.com', 'test@gmail.com', 'blablabla@gmail.com', '123@gmail.com', 'admin123@gmail.com', 'admin123@gmail.com']

#list not treated transformed in set to remove duplicates
unique_list = set(raw_list)

#using method add to add a value in the set
unique_list.add('admin321@gmail.com')

#print the set
print(unique_list)
# Out:
# {'emailcriativo@gmail.com', '123@gmail.com', 'test@gmail.com', 'admin123@gmail.com', 'admin321@gmail.com', 'blablabla@gmail.com'}
