# %%
coordenade = (-23.5505, -46.6333)

print(coordenade[0])

#try of change a tuple value
try:
  coordenade[0] = 1

except Exception as error:
  print(f'erro: {error}')
# Out:
# -23.5505
# erro: 'tuple' object does not support item assignment
