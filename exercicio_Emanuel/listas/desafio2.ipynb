# %%
clients = {'nome':'test', 'email':'test@teste.com', 'plano':'basico'}

#modification in 'plano'
clients['plano'] = 'premium'

#adiction of element 'status'
clients['status'] = 'ativo'

#print of element 'email'
print(f'email: {clients['email']}')
# Out:
# test
